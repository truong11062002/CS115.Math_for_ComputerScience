# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/csbu014/iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head(n=7)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa

# %%
countNULL = df.isna().sum()
null_columns = countNULL[countNULL > 0]
null_columns
# Out:
# Series([], dtype: int64)

# %%
df_1 = pd.read_csv('/content/drive/MyDrive/csbu014/data1.csv')

# %%
df_1
# Out:
#     ID   Age     Sex  Height      Grade Good-looking
# 0    1  21.0    Male   171.0       Good          Yes
# 1    2  20.0    Male   170.0        Bad           No
# 2    3  19.0  Female     NaN        Bad           No
# 3    4  17.0    Male   165.0  Excellent          Yes
# 4    5   NaN  Female   166.0       Good          Yes
# 5    6   NaN  Female   180.0  Excellent          Yes
# 6    7  30.0    Male   170.0       Good           No
# 7    8  60.0    Male     NaN        Bad           No
# 8    9  20.0  Female   167.0        NaN          Yes
# 9   10  21.0    Male   290.0       Good          Yes
# 10  11  22.0  Female   190.0        NaN           No
# 11  12   NaN    Male   163.0        NaN          Yes

# %%
countNULL = df_1.isna().sum()
null_columns = countNULL[countNULL > 0]
null_columns
# Out:
# Age       3
# Height    2
# Grade     3
# dtype: int64

# %%
df_1_remove = df_1.dropna(inplace=False)

# %%
df_1_remove
# Out:
#    ID   Age   Sex  Height      Grade Good-looking
# 0   1  21.0  Male   171.0       Good          Yes
# 1   2  20.0  Male   170.0        Bad           No
# 3   4  17.0  Male   165.0  Excellent          Yes
# 6   7  30.0  Male   170.0       Good           No
# 9  10  21.0  Male   290.0       Good          Yes

# %%
df_1
# Out:
#     ID   Age     Sex  Height      Grade Good-looking
# 0    1  21.0    Male   171.0       Good          Yes
# 1    2  20.0    Male   170.0        Bad           No
# 2    3  19.0  Female     NaN        Bad           No
# 3    4  17.0    Male   165.0  Excellent          Yes
# 4    5   NaN  Female   166.0       Good          Yes
# 5    6   NaN  Female   180.0  Excellent          Yes
# 6    7  30.0    Male   170.0       Good           No
# 7    8  60.0    Male     NaN        Bad           No
# 8    9  20.0  Female   167.0        NaN          Yes
# 9   10  21.0    Male   290.0       Good          Yes
# 10  11  22.0  Female   190.0        NaN           No
# 11  12   NaN    Male   163.0        NaN          Yes

# %%
df_1.dropna(inplace=True)

# %%
df_1
# Out:
#    ID   Age   Sex  Height      Grade Good-looking
# 0   1  21.0  Male   171.0       Good          Yes
# 1   2  20.0  Male   170.0        Bad           No
# 3   4  17.0  Male   165.0  Excellent          Yes
# 6   7  30.0  Male   170.0       Good           No
# 9  10  21.0  Male   290.0       Good          Yes

# %%
df_1 = pd.read_csv('/content/drive/MyDrive/csbu014/data1.csv')

# %%
df_1
# Out:
#     ID   Age     Sex  Height      Grade Good-looking
# 0    1  21.0    Male   171.0       Good          Yes
# 1    2  20.0    Male   170.0        Bad           No
# 2    3  19.0  Female     NaN        Bad           No
# 3    4  17.0    Male   165.0  Excellent          Yes
# 4    5   NaN  Female   166.0       Good          Yes
# 5    6   NaN  Female   180.0  Excellent          Yes
# 6    7  30.0    Male   170.0       Good           No
# 7    8  60.0    Male     NaN        Bad           No
# 8    9  20.0  Female   167.0        NaN          Yes
# 9   10  21.0    Male   290.0       Good          Yes
# 10  11  22.0  Female   190.0        NaN           No
# 11  12   NaN    Male   163.0        NaN          Yes

# %%
mean_age = df_1['Age'].mean()

# %%
mean_age
# Out:
# 25.555555555555557

# %%
median_height = df_1['Height'].median()

# %%
median_height
# Out:
# 170.0

# %%
mode_grade = df_1['Grade'].mode()[0]

# %%
mode_grade
# Out:
# 'Good'

# %%
df_1['Age'].fillna(value=int(mean_age), inplace=True)
df_1['Height'].fillna(value=median_height, inplace=True)
df_1['Grade'].fillna(value=mode_grade, inplace=True)

# %%
df_1
# Out:
#     ID   Age     Sex  Height      Grade Good-looking
# 0    1  21.0    Male   171.0       Good          Yes
# 1    2  20.0    Male   170.0        Bad           No
# 2    3  19.0  Female   170.0        Bad           No
# 3    4  17.0    Male   165.0  Excellent          Yes
# 4    5  25.0  Female   166.0       Good          Yes
# 5    6  25.0  Female   180.0  Excellent          Yes
# 6    7  30.0    Male   170.0       Good           No
# 7    8  60.0    Male   170.0        Bad           No
# 8    9  20.0  Female   167.0       Good          Yes
# 9   10  21.0    Male   290.0       Good          Yes
# 10  11  22.0  Female   190.0       Good           No
# 11  12  25.0    Male   163.0       Good          Yes

# %%
import seaborn as sbn
sbn.boxplot(df_1['Height'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Q1 = df_1['Height'].quantile(0.25)
Q3 = df_1['Height'].quantile(0.75)

# %%
Q1
# Out:
# 166.75

# %%
Q3
# Out:
# 173.25

# %%
IQR = Q3 - Q1
low_fence = Q1 - 1.5*IQR
up_fence = Q3 + 1.5*IQR

# %%
df_1[((df_1['Height'] < low_fence) | (df_1['Height'] > up_fence))]
# Out:
#     ID   Age     Sex  Height Grade Good-looking
# 9   10  21.0    Male   290.0  Good          Yes
# 10  11  22.0  Female   190.0  Good           No

# %%
df_1 = df_1[~((df_1['Height'] < low_fence) | (df_1['Height'] > up_fence))]

# %%
df_1
# Out:
#     ID   Age     Sex  Height      Grade Good-looking
# 0    1  21.0    Male   171.0       Good          Yes
# 1    2  20.0    Male   170.0        Bad           No
# 2    3  19.0  Female   170.0        Bad           No
# 3    4  17.0    Male   165.0  Excellent          Yes
# 4    5  25.0  Female   166.0       Good          Yes
# 5    6  25.0  Female   180.0  Excellent          Yes
# 6    7  30.0    Male   170.0       Good           No
# 7    8  60.0    Male   170.0        Bad           No
# 8    9  20.0  Female   167.0       Good          Yes
# 11  12  25.0    Male   163.0       Good          Yes

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
df_1['Sex'] = label_encoder.fit_transform(df_1['Sex'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_1
# Out:
#     ID   Age  Sex  Height      Grade Good-looking
# 0    1  21.0    1   171.0       Good          Yes
# 1    2  20.0    1   170.0        Bad           No
# 2    3  19.0    0   170.0        Bad           No
# 3    4  17.0    1   165.0  Excellent          Yes
# 4    5  25.0    0   166.0       Good          Yes
# 5    6  25.0    0   180.0  Excellent          Yes
# 6    7  30.0    1   170.0       Good           No
# 7    8  60.0    1   170.0        Bad           No
# 8    9  20.0    0   167.0       Good          Yes
# 11  12  25.0    1   163.0       Good          Yes

# %%
df_1.reset_index(drop=True, inplace=True)

# %%
df_1
# Out:
#    ID   Age  Sex  Height      Grade Good-looking
# 0   1  21.0    1   171.0       Good          Yes
# 1   2  20.0    1   170.0        Bad           No
# 2   3  19.0    0   170.0        Bad           No
# 3   4  17.0    1   165.0  Excellent          Yes
# 4   5  25.0    0   166.0       Good          Yes
# 5   6  25.0    0   180.0  Excellent          Yes
# 6   7  30.0    1   170.0       Good           No
# 7   8  60.0    1   170.0        Bad           No
# 8   9  20.0    0   167.0       Good          Yes
# 9  12  25.0    1   163.0       Good          Yes

# %%
from sklearn.preprocessing import OneHotEncoder
onehot_encoder = OneHotEncoder(sparse=False)

# %%
name_col = 'Grade'

# %%
data_new = onehot_encoder.fit_transform(df_1[[name_col]])

# %%
grade_column = pd.DataFrame(data=data_new, columns=onehot_encoder.get_feature_names([name_col]))

# %%
df_1 = pd.concat([df_1.drop(columns=[name_col, 'Good-looking']), grade_column, df_1['Good-looking']], axis=1)

# %%
df_1
# Out:
#    ID   Age  Sex  Height  Grade_Bad  Grade_Excellent  Grade_Good Good-looking
# 0   1  21.0    1   171.0        0.0              0.0         1.0          Yes
# 1   2  20.0    1   170.0        1.0              0.0         0.0           No
# 2   3  19.0    0   170.0        1.0              0.0         0.0           No
# 3   4  17.0    1   165.0        0.0              1.0         0.0          Yes
# 4   5  25.0    0   166.0        0.0              0.0         1.0          Yes
# 5   6  25.0    0   180.0        0.0              1.0         0.0          Yes
# 6   7  30.0    1   170.0        0.0              0.0         1.0           No
# 7   8  60.0    1   170.0        1.0              0.0         0.0           No
# 8   9  20.0    0   167.0        0.0              0.0         1.0          Yes
# 9  12  25.0    1   163.0        0.0              0.0         1.0          Yes

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_1.drop(columns=['ID', 'Good-looking'])
y = df_1['Good-looking']

# %%
X
# Out:
#     Age  Sex  Height  Grade_Bad  Grade_Excellent  Grade_Good
# 0  21.0    1   171.0        0.0              0.0         1.0
# 1  20.0    1   170.0        1.0              0.0         0.0
# 2  19.0    0   170.0        1.0              0.0         0.0
# 3  17.0    1   165.0        0.0              1.0         0.0
# 4  25.0    0   166.0        0.0              0.0         1.0
# 5  25.0    0   180.0        0.0              1.0         0.0
# 6  30.0    1   170.0        0.0              0.0         1.0
# 7  60.0    1   170.0        1.0              0.0         0.0
# 8  20.0    0   167.0        0.0              0.0         1.0
# 9  25.0    1   163.0        0.0              0.0         1.0

# %%
y
# Out:
# 0    Yes
# 1     No
# 2     No
# 3    Yes
# 4    Yes
# 5    Yes
# 6     No
# 7     No
# 8    Yes
# 9    Yes
# Name: Good-looking, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train
# Out:
#     Age  Sex  Height  Grade_Bad  Grade_Excellent  Grade_Good
# 5  25.0    0   180.0        0.0              1.0         0.0
# 2  19.0    0   170.0        1.0              0.0         0.0
# 0  21.0    1   171.0        0.0              0.0         1.0
# 6  30.0    1   170.0        0.0              0.0         1.0
# 7  60.0    1   170.0        1.0              0.0         0.0
# 3  17.0    1   165.0        0.0              1.0         0.0
# 1  20.0    1   170.0        1.0              0.0         0.0

# %%
X_test
# Out:
#     Age  Sex  Height  Grade_Bad  Grade_Excellent  Grade_Good
# 4  25.0    0   166.0        0.0              0.0         1.0
# 8  20.0    0   167.0        0.0              0.0         1.0
# 9  25.0    1   163.0        0.0              0.0         1.0

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()

# %%
X_train[['Height']] = min_max_scaler.fit_transform(X_train[['Height']])
X_test[['Height']] = min_max_scaler.fit_transform(X_test[['Height']])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
X_train
# Out:
#     Age  Sex    Height  Grade_Bad  Grade_Excellent  Grade_Good
# 5  25.0    0  1.000000        0.0              1.0         0.0
# 2  19.0    0  0.333333        1.0              0.0         0.0
# 0  21.0    1  0.400000        0.0              0.0         1.0
# 6  30.0    1  0.333333        0.0              0.0         1.0
# 7  60.0    1  0.333333        1.0              0.0         0.0
# 3  17.0    1  0.000000        0.0              1.0         0.0
# 1  20.0    1  0.333333        1.0              0.0         0.0

# %%
X_test
# Out:
#     Age  Sex  Height  Grade_Bad  Grade_Excellent  Grade_Good
# 4  25.0    0    0.75        0.0              0.0         1.0
# 8  20.0    0    1.00        0.0              0.0         1.0
# 9  25.0    1    0.00        0.0              0.0         1.0

# %%
from sklearn.preprocessing import StandardScaler
standard_scaler = StandardScaler()

# %%
X_train[['Age']] = standard_scaler.fit_transform(X_train[['Age']])
X_test[['Age']] = standard_scaler.fit_transform(X_test[['Age']])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
X_train
# Out:
#         Age  Sex    Height  Grade_Bad  Grade_Excellent  Grade_Good
# 5 -0.174896    0  1.000000        0.0              1.0         0.0
# 2 -0.606991    0  0.333333        1.0              0.0         0.0
# 0 -0.462959    1  0.400000        0.0              0.0         1.0
# 6  0.185184    1  0.333333        0.0              0.0         1.0
# 7  2.345659    1  0.333333        1.0              0.0         0.0
# 3 -0.751022    1  0.000000        0.0              1.0         0.0
# 1 -0.534975    1  0.333333        1.0              0.0         0.0

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_clf = KNeighborsClassifier(n_neighbors=3, p=2)

# %%
knn_clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
y_pred = knn_clf.predict(X_test)

# %%
y_pred
# Out:
# array(['Yes', 'Yes', 'No'], dtype=object)

# %%
y_test
# Out:
# 4    Yes
# 8    Yes
# 9    Yes
# Name: Good-looking, dtype: object

# %%
X_test
# Out:
#         Age  Sex  Height  Grade_Bad  Grade_Excellent  Grade_Good
# 4  0.707107    0    0.75        0.0              0.0         1.0
# 8 -1.414214    0    1.00        0.0              0.0         1.0
# 9  0.707107    1    0.00        0.0              0.0         1.0

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test, y_pred)

# %%
accuracy
# Out:
# 0.6666666666666666

# %%
from sklearn.metrics import classification_report

# %%
clf_report = classification_report(y_test, y_pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#           No       0.00      0.00      0.00         0
#          Yes       1.00      0.67      0.80         3
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.33      0.40         3
# weighted avg       1.00      0.67      0.80         3
